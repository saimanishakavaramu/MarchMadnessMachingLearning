# %%
import requests
from bs4 import BeautifulSoup as bs
import csv
import pandas as pd

# %%
base_url = "https://www.sports-reference.com/cbb/"
add_on = "seasons/men/"+"2021"+"-advanced-school-stats.html"
response = requests.get(base_url + add_on)

# %%
team_name = []
tournament_success = []

with open('Tournament_Results/2021_Tournament.csv', 'r') as csv_file:
    csv_reader = csv.reader(csv_file)
    for row in csv_reader:
        team_name.append(row[0])
        tournament_success.append(int(row[1]))

simple_rating_system = []
strength_of_schedule = []
pace_factor = []
offensive_rating = []
free_throw_attempt_rate = []
three_point_attempt_rate = []
true_shooting_percentage = []
total_rebound_percentage = []
assist_percentage = []
steal_percentage = []
block_percentage = []
effective_field_goal_percentage = []
turnover_percentage = []
offensive_rebound_percentage = []

print(team_name)
# Out:
# ['Baylor', 'Hartford', 'North Carolina', 'Wisconsin', 'Purdue', 'North Texas', 'Villanova', 'Winthrop', 'Ohio State', 'Oral Roberts', 'Florida', 'Virginia Tech', 'Arkansas', 'Colgate', 'Texas Tech', 'Utah State', 'Illinois', 'Drexel', 'Loyola (IL)', 'Georgia Tech', 'Oklahoma State', 'Liberty', 'Tennessee', 'Oregon State', 'Houston', 'Cleveland State', 'Clemson', 'Rutgers', 'West Virginia', 'Morehead State', 'San Diego State', 'Syracuse', 'Gonzaga', 'Norfolk State', 'Oklahoma', 'Missouri', 'Virginia', 'Ohio', 'Creighton', 'UC Santa Barbara', 'Iowa', 'Grand Canyon', 'Oregon', 'Virginia Commonwealth', 'Kansas', 'Eastern Washington', 'Southern California', 'Drake', 'Michigan', 'Texas Southern', 'Louisiana State', 'St. Bonaventure', 'Florida State', 'UNC Greensboro', 'Colorado', 'Georgetown', 'Alabama', 'Iona', 'Connecticut', 'Maryland', 'Texas', 'Abilene Christian', 'Brigham Young', 'UCLA']

# %%
soup = bs(response.content, 'html.parser')
table_lst = soup.select('tbody')[0].select('tr')

#Loopthrough Function
def loop_through(tag):
    return tag.get_text().replace('\xa0NCAA', '').strip()

Dict = {}

#for team in table_lst_2023:
for teams in table_lst:
    team = list(map(loop_through, teams))
    teamName = team[1]
    if teamName != '' and teamName in team_name:
        Srs = float(team[6])
        Sos = float(team[7])
        Pace = float(team[21])
        ORtg = float(team[22])
        Ftr = float(team[23])
        PAr3 = float(team[24])
        Ts = float(team[25])
        Trb = float(team[26])
        Ast = float(team[27])
        Stl = float(team[28])
        Blk = float(team[29])
        eFG = float(team[30])
        Tov = float(team[31])
        Orb = float(team[32])
        Dict[teamName] = [Srs, Sos, Pace, ORtg, Ftr, PAr3, Ts, Trb, Ast, Stl, Blk, eFG, Tov, Orb]

#print((Dict_2022.keys()))
for name in team_name:
    if name not in Dict.keys():
        print(name)

# %%
for teamName in team_name:
    data = Dict[teamName]
    simple_rating_system.append(data[0])
    strength_of_schedule.append(data[1])
    pace_factor.append(data[2])
    offensive_rating.append(data[3])
    free_throw_attempt_rate.append(data[4])
    three_point_attempt_rate.append(data[5])
    true_shooting_percentage.append(data[6])
    total_rebound_percentage.append(data[7])
    assist_percentage.append(data[8])
    steal_percentage.append(data[9])
    block_percentage.append(data[10])
    effective_field_goal_percentage.append(data[11])
    turnover_percentage.append(data[12])
    offensive_rebound_percentage.append(data[13])

# %%
#Pandas Dataframe for 2021
data_2021 = {
    "team_name" : team_name,
    "year" : [2021] * 64,
    "tournament_success" : tournament_success,
    "simple_rating_system" : simple_rating_system,
    "strength_of_schedule" : strength_of_schedule,
    "pace_factor" : pace_factor,
    "offensive_rating" : offensive_rating,
    "free_throw_attempt_rate" : free_throw_attempt_rate,
    "three_point_attempt_rate" : three_point_attempt_rate,
    "true_shooting_percentage" : true_shooting_percentage,
    "total_rebound_percentage" : total_rebound_percentage,
    "assist_percentage" : assist_percentage,
    "steal_percentage" : steal_percentage,
    "block_percentage" : block_percentage,
    "effective_field_goal_percentage" : effective_field_goal_percentage,
    "turnover_percentage" : turnover_percentage,
    "offensive_rebound_percentage" : offensive_rebound_percentage  
}

df_2021 = pd.DataFrame(data=data_2021)
df_2021
# Out:
#             team_name  year  tournament_success  simple_rating_system  \
# 0              Baylor  2021                   6                 24.83
# 1            Hartford  2021                   0                 -3.45
# 2      North Carolina  2021                   0                 14.79
# 3           Wisconsin  2021                   1                 17.22
# 4              Purdue  2021                   0                 15.55
# ..                ...   ...                 ...                   ...
# 59           Maryland  2021                   1                 13.94
# 60              Texas  2021                   0                 15.51
# 61  Abilene Christian  2021                   1                  6.27
# 62      Brigham Young  2021                   0                 15.19
# 63               UCLA  2021                   4                 16.30
#
#     strength_of_schedule  pace_factor  offensive_rating  \
# 0                   7.40         69.6             118.7
# 1                  -4.95         67.0              97.6
# 2                   9.52         71.8             104.8
# 3                  11.93         65.8             105.4
# 4                  11.23         66.5             105.8
# ..                   ...          ...               ...
# 59                 11.97         65.9             104.5
# 60                  9.36         69.5             105.5
# 61                 -6.37         72.0             105.2
# 62                  7.23         70.2             109.8
# 63                 11.34         65.4             108.4
#
#     free_throw_attempt_rate  three_point_attempt_rate  \
# 0                     0.265                     0.384
# 1                     0.286                     0.425
# 2                     0.342                     0.279
# 3                     0.262                     0.409
# 4                     0.317                     0.378
# ..                      ...                       ...
# 59                    0.329                     0.433
# 60                    0.339                     0.421
# 61                    0.339                     0.367
# 62                    0.275                     0.394
# 63                    0.316                     0.316
#
#     true_shooting_percentage  total_rebound_percentage  assist_percentage  \
# 0                      0.586                      53.2               55.3
# 1                      0.530                      48.7               47.0
# 2                      0.514                      56.8               55.3
# 3                      0.533                      49.0               54.0
# 4                      0.542                      54.5               55.9
# ..                       ...                       ...                ...
# 59                     0.564                      49.1               55.1
# 60                     0.559                      52.7               50.9
# 61                     0.540                      51.5               65.3
# 62                     0.580                      54.7               56.2
# 63                     0.551                      52.6               51.1
#
#     steal_percentage  block_percentage  effective_field_goal_percentage  \
# 0               12.7              10.3                            0.565
# 1               10.3               6.6                            0.499
# 2                9.8              12.8                            0.483
# 3                8.5              10.7                            0.499
# 4                7.6              11.4                            0.510
# ..               ...               ...                              ...
# 59               7.6              10.0                            0.538
# 60               9.2              10.4                            0.529
# 61              13.5               8.9                            0.512
# 62               6.5               7.2                            0.556
# 63               7.3               7.9                            0.520
#
#     turnover_percentage  offensive_rebound_percentage
# 0                  14.0                          36.4
# 1                  17.5                          24.3
# 2                  16.6                          40.6
# 3                  12.1                          23.6
# 4                  16.0                          32.6
# ..                  ...                           ...
# 59                 15.3                          20.2
# 60                 18.0                          30.9
# 61                 16.2                          31.3
# 62                 16.4                          28.6
# 63                 13.6                          29.2
#
# [64 rows x 17 columns]
